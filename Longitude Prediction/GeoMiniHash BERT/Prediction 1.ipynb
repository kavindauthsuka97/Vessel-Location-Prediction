# %% [markdown]
# 2023 to 2024/03

# %% [markdown]
# #### 1.  Import Libraries and Setup

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, TimeDistributed
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
# Out:
# 2024-11-11 14:12:20.004945: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-11 14:12:20.020435: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1731334340.039337   12835 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1731334340.044929   12835 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# #### 2. Load and Preprocess Dataset

# %%
# Load dataset
data = pd.read_csv('LL_data.csv')
data['Received_Timestamp'] = pd.to_datetime(data['Received_Timestamp'])
data['Latitude'] = pd.to_numeric(data['Latitude'], errors='coerce')
data = data.dropna()
data.set_index('Received_Timestamp', inplace=True)

# Resample data to 6-hour intervals
data = data.resample('6H').mean()
data = data.interpolate(method='linear')

# Normalize the latitude data
scaler = MinMaxScaler()
data[['Longitude']] = scaler.fit_transform(data[['Longitude']])

# Split data into training and testing sets
training_set = data.loc['2023':'2024-02']
testing_set = data.loc['2024-03':]
# Out:
# /tmp/ipykernel_12835/2989265505.py:9: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   data = data.resample('6H').mean()

# %% [markdown]
# #### 3.  Sliding Window Processing

# %%
# Sliding window parameters
input_window_size = 28
output_window_size = 1
stride = 1

# Prepare data for sequence processing
X, y = [], []
for i in range(0, len(training_set) - input_window_size - output_window_size + 1, stride):
    input_window = training_set.iloc[i:i+input_window_size][['Longitude']]
    output_window = training_set.iloc[i+input_window_size:i+input_window_size+output_window_size][['Longitude']]
    X.append(input_window.values)
    y.append(output_window.values[-1])

# Convert lists to numpy arrays
X, y = np.array(X), np.array(y)

# Print shapes
print(f"Number of samples: {X.shape[0]}")
print(f"Input shape: {X.shape}, Target shape: {y.shape}")
# Out:
# Number of samples: 1672
# Input shape: (1672, 28, 1), Target shape: (1672, 1)

# %% [markdown]
# #### 4.  BERT-based Model Architecture for Latitude Prediction

# %%
# Define an improved BERT-like model architecture for latitude encoding and prediction
def build_geohash_bert_model(input_shape, units=128, dense_units=64, dropout_rate=0.3, learning_rate=0.0005):
    inputs = Input(shape=input_shape)
    
    # First Dense layer to encode input sequence with added Dropout
    x = TimeDistributed(Dense(units, activation='relu'))(inputs)
    x = Dropout(dropout_rate)(x)
    x = TimeDistributed(Dense(units, activation='relu'))(x)
    x = Dropout(dropout_rate)(x)
    
    # Embedding dense layers to capture spatial context, with Batch Normalization
    x = TimeDistributed(Dense(dense_units, activation='relu'))(x)
    x = Dropout(dropout_rate)(x)
    
    # Additional dense layer for enhanced feature representation
    x = TimeDistributed(Dense(dense_units // 2, activation='relu'))(x)
    x = Dropout(dropout_rate)(x)
    
    # Final layer to capture the last time step output for prediction
    outputs = Dense(1)(x[:, -1, :])  # Select last time step for the output prediction
    
    # Compile the model with a lower learning rate for better convergence
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')
    return model

# Initialize model with the improved structure
input_shape = (input_window_size, 1)  # Sequence has 28 time steps with 1 feature (Latitude)
model = build_geohash_bert_model(input_shape=input_shape)
print(model.summary())
# Out:
# 2024-11-11 14:12:23.899307: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 28, 128)        │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 28, 128)        │             0 │
# ...

# %%
# Early stopping and learning rate reduction with higher patience
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train the model with a validation split and updated callbacks
history = model.fit(X, y, epochs=150, batch_size=32, validation_split=0.3, 
                    callbacks=[early_stopping, lr_scheduler], verbose=1)

# Plot training history
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - loss: 0.1471 - val_loss: 0.0081 - learning_rate: 5.0000e-04
# Epoch 2/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0321 - val_loss: 0.0124 - learning_rate: 5.0000e-04
# Epoch 3/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0273 - val_loss: 0.0121 - learning_rate: 5.0000e-04
# Epoch 4/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0222 - val_loss: 0.0121 - learning_rate: 5.0000e-04
# Epoch 5/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0199 - val_loss: 0.0133 - learning_rate: 5.0000e-04
# Epoch 6/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0187 - val_loss: 0.0151 - learning_rate: 5.0000e-04
# Epoch 7/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0150 - val_loss: 0.0169 - learning_rate: 2.5000e-04
# Epoch 8/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0148 - val_loss: 0.0183 - learning_rate: 2.5000e-04
# Epoch 9/150
# ...

# %% [markdown]
# #### 5.  Prepare Testing Set

# %%
# Prepare testing set with the same sliding window approach
X_test, y_test = [], []
for i in range(0, len(testing_set) - input_window_size - output_window_size + 1, stride):
    input_window = testing_set.iloc[i:i+input_window_size][['Longitude']]
    output_window = testing_set.iloc[i+input_window_size:i+input_window_size+output_window_size][['Longitude']]
    X_test.append(input_window.values)
    y_test.append(output_window.values[-1])

X_test, y_test = np.array(X_test), np.array(y_test)
print(f"Number of test samples: {X_test.shape[0]}")
print(f"Test input shape: {X_test.shape}, Test target shape: {y_test.shape}")
# Out:
# Number of test samples: 648
# Test input shape: (648, 28, 1), Test target shape: (648, 1)

# %% [markdown]
# #### 6. Test the Model

# %%
# Make predictions for Longitude instead of Latitude
y_pred = model.predict(X_test)

# Calculate mean squared error
error = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error on the Testing Set: {error}")

# Integrate predictions into the testing set for visualization
# Change the column name to 'Predicted_Longitude'
predictions_df = pd.DataFrame(y_pred, columns=['Predicted_Longitude'])
# Initialize NaN values for 'Predicted_Longitude' column in the testing set
testing_set['Predicted_Longitude'] = np.nan
# Assign predictions to the 'Predicted_Longitude' column
testing_set.iloc[input_window_size:input_window_size + len(y_pred), -1] = predictions_df.values

# Plot results
months = {'April': '2024-04', 'May': '2024-05', 'June': '2024-06', 'July': '2024-07', 'August': '2024-08'}

for month_name, month_str in months.items():
    monthly_data = testing_set[testing_set.index.to_period('M') == month_str]
    
    plt.figure(figsize=(12, 6))
    # Change 'Latitude' to 'Longitude' and 'Predicted_Latitude' to 'Predicted_Longitude'
    plt.plot(monthly_data.index, monthly_data['Longitude'], label='Longitude', color='blue')
    plt.plot(monthly_data.index, monthly_data['Predicted_Longitude'], label='Predicted Longitude', color='orange')
    plt.title(f'{month_name} 2024 - Longitude vs Predicted Longitude')
    plt.xlabel('Received Timestamp')
    plt.ylabel('Longitude')
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# Mean Squared Error on the Testing Set: 0.011210341233222704
# /tmp/ipykernel_12835/2581439020.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_set['Predicted_Longitude'] = np.nan
