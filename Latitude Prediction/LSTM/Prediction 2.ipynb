# %% [markdown]
# Training set - 2023 Jan to 2024 March
# Input window = 28

# %% [markdown]
# #### 1. Import the libraries

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
import matplotlib.pyplot as plt

# %%
# !pip install tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
# Out:
# Requirement already satisfied: tensorflow in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (2.17.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: opt-einsum>=2.3.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: libclang>=13.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: h5py>=3.10.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: keras>=3.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: setuptools in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: google-pasta>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (1.65.4)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: absl-py>=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: optree in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: rich in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/anaconda/envs/azureml_py38/lib/python3.10/site-packages/numpy-1.23.5.dist-info/METADATA'

# %%
pip install scipy scikit-learn
# Out:
# Requirement already satisfied: scipy in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (1.14.1)
# Requirement already satisfied: scikit-learn in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from scipy) (2.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 2. Pre processing the dataset

# %%
# load dataset
data = pd.read_csv('LL_data.csv')

# %%
data.tail()
# Out:
#          Received_Timestamp  Latitude  Longitude
# 796631  2024-08-16 20:26:55  6.301900  94.509340
# 796632  2024-08-16 20:41:52  6.304237  94.558950
# 796633  2024-08-16 20:44:07  6.304650  94.566895
# 796634  2024-08-16 20:44:45  6.304758  94.569090
# 796635  2024-08-16 21:01:24  6.306820  94.625694

# %%
data['Received_Timestamp'] = pd.to_datetime(data['Received_Timestamp'])  # Convert to datetime
data['Latitude'] = pd.to_numeric(data['Latitude'], errors='coerce')       # Convert to numeric, handling errors
data['Longitude'] = pd.to_numeric(data['Longitude'], errors='coerce')     # Convert to numeric, handling errors
data = data.dropna()  # Drop rows with NaN values if any remain

# %%
data.set_index('Received_Timestamp', inplace=True)  # Set datetime as the index

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 796636 entries, 2023-01-01 00:36:49 to 2024-08-16 21:01:24
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Latitude   796636 non-null  float64
#  1   Longitude  796636 non-null  float64
# dtypes: float64(2)
# memory usage: 18.2 MB

# %%
# Resample data to six-hour bins, handling empty bins with interpolation
data = data.resample('6H').mean()  # Bin by six hours with mean aggregation
data = data.interpolate(method='linear')  # Linear interpolation for missing bins
# Out:
# /tmp/ipykernel_122161/4293368568.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   data = data.resample('6H').mean()  # Bin by six hours with mean aggregation

# %%
data.head()
# Out:
#                       Latitude  Longitude
# Received_Timestamp
# 2023-01-01 00:00:00  23.954669  61.666054
# 2023-01-01 06:00:00  23.719084  62.527122
# 2023-01-01 12:00:00  23.347651  63.845577
# 2023-01-01 18:00:00  23.076742  64.817208
# 2023-01-02 00:00:00  22.740178  66.021411

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2376 entries, 2023-01-01 00:00:00 to 2024-08-16 18:00:00
# Freq: 6h
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Latitude   2376 non-null   float64
#  1   Longitude  2376 non-null   float64
# dtypes: float64(2)
# memory usage: 55.7 KB

# %%
# Normalize the Latitude and Longitude values
# Initialize a MinMaxScaler to scale latitude and longitude data to the range [0, 1]
scaler = MinMaxScaler()
# Apply the scaler to the 'Latitude' and 'Longitude' columns
data[['Latitude', 'Longitude']] = scaler.fit_transform(data[['Latitude', 'Longitude']])

# %%
# Training set: Entire year of 2023 and up to August 2024
training_set = data.loc['2023':'2024-02']

# Testing set: Remaining months in 2024, starting from September 2024
testing_set = data.loc['2024-03':]

# %%
training_set.head()
# Out:
#                      Latitude  Longitude
# Received_Timestamp
# 2023-01-01 00:00:00  0.545963   0.603455
# 2023-01-01 06:00:00  0.543781   0.609879
# 2023-01-01 12:00:00  0.540342   0.619715
# 2023-01-01 18:00:00  0.537833   0.626964
# 2023-01-02 00:00:00  0.534716   0.635948

# %%
testing_set.head()
# Out:
#                      Latitude  Longitude
# Received_Timestamp
# 2024-03-01 00:00:00  0.541115   0.001624
# 2024-03-01 06:00:00  0.548333   0.001873
# 2024-03-01 12:00:00  0.559416   0.002246
# 2024-03-01 18:00:00  0.570363   0.002649
# 2024-03-02 00:00:00  0.581073   0.003018

# %% [markdown]
# #### 3. Sliding window approach

# %%
# Define the input window size (20 data points)
input_window_size = 28
# Define the output window size (1 data point)
output_window_size = 1
# Define the stride, which determines how much to move forward for each new window (1 data point)
stride = 1

# %%
# Apply sliding window to create sequences
# Initialize empty lists to store the input (X) and output (y) sequences
X, y = [], []

# Loop through the dataset to create windows of input and output sequences
for i in range(0, len(training_set) - input_window_size - output_window_size + 1, stride):
    # Define the input window, which is a slice of 20 data points
    input_window = training_set.iloc[i:i+input_window_size][['Latitude']]
    # Define the output window, which is a slice of 1 data point immediately following the input window
    output_window = training_set.iloc[i+input_window_size:i+input_window_size+output_window_size][['Latitude']]
    # Append the input window data to X and the last value of output window to y
    X.append(input_window.values)
    y.append(output_window.values[-1])

# %%
# Convert X and y lists to numpy arrays for model input
X, y = np.array(X), np.array(y)

# Print the number of samples created
print(f"Number of samples: {X.shape[0]}")
# Print the shape of the input (X) and output (y) arrays
print(f"Input shape: {X.shape}, Target shape: {y.shape}")
# Out:
# Number of samples: 1672
# Input shape: (1672, 28, 1), Target shape: (1672, 1)

# %% [markdown]
# #### 4. Define LSTM model architecture

# %%
# Import necessary modules
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Define a function to create an LSTM model with specified hyperparameters
def build_model(units=50, lstm_layers=2, dropout_rate=0.2, recurrent_dropout=0.2, activation='tanh', learning_rate=0.001):
    """
    Builds an LSTM model with the given parameters.

    Parameters:
        units (int): Number of units in each LSTM layer.
        lstm_layers (int): Number of stacked LSTM layers.
        dropout_rate (float): Dropout rate for regularization.
        recurrent_dropout (float): Dropout rate for the recurrent connections.
        activation (str): Activation function for LSTM layers.
        learning_rate (float): Learning rate for the optimizer.

    Returns:
        model (Sequential): Compiled Keras model ready for training.
    """
    # Initialize a Sequential model
    model = Sequential()
    
    # Add LSTM layers
    for i in range(lstm_layers - 1):
        # Add intermediate LSTM layers with return_sequences=True for stacking
        model.add(LSTM(units=units, activation=activation, return_sequences=True, dropout=dropout_rate, recurrent_dropout=recurrent_dropout))
    
    # Add the final LSTM layer without return_sequences, as this is a many-to-one model
    model.add(LSTM(units=units, activation=activation, dropout=dropout_rate, recurrent_dropout=recurrent_dropout))
    
    # Add a Dense layer with 1 unit for output (for regression)
    model.add(Dense(1))
    
    # Initialize the Adam optimizer with the specified learning rate
    optimizer = Adam(learning_rate=learning_rate)
    
    # Compile the model using mean squared error (MSE) as the loss function, which is suitable for regression
    model.compile(optimizer=optimizer, loss='mse')
    
    return model

# Initialize variables to keep track of the best model and lowest validation loss
best_model = None
best_loss = float('inf')  # Start with a high initial loss for comparison

# Define hyperparameter grids for tuning
units_list = [50, 100, 150]       # Different numbers of units to try in LSTM layers
layers_list = [1, 2, 3]           # Different numbers of LSTM layers to try
dropout_list = [0.2, 0.3, 0.5]    # Different dropout rates to test for regularization
learning_rates = [0.0001, 0.001, 0.005]  # Different learning rates for the optimizer
batch_sizes = [16, 32, 48]        # Different batch sizes for training

# Perform grid search across all combinations of hyperparameters
for units in units_list:
    for layers in layers_list:
        for dropout in dropout_list:
            for lr in learning_rates:
                for batch_size in batch_sizes:
                    # Print the current combination of hyperparameters being tested
                    print(f"Training model with units={units}, layers={layers}, dropout={dropout}, lr={lr}, batch_size={batch_size}")
                    
                    # Build a model with the current set of hyperparameters
                    model = build_model(units=units, lstm_layers=layers, dropout_rate=dropout, learning_rate=lr)
                    
                    # Define early stopping to stop training if validation loss doesn't improve for a number of epochs
                    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
                    
                    # Define learning rate scheduler to reduce learning rate if validation loss plateaus
                    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
                    
                    # Train the model on the data with a validation split of 30%
                    # Early stopping and learning rate scheduler will be used as callbacks
                    history = model.fit(X, y, 
                                        epochs=100, 
                                        batch_size=batch_size, 
                                        validation_split=0.3, 
                                        callbacks=[early_stopping, lr_scheduler], 
                                        verbose=1)
                    
                    # Retrieve the minimum validation loss achieved during training
                    val_loss = min(history.history['val_loss'])
                    
                    # Check if the current model has achieved a lower validation loss than the best so far
                    if val_loss < best_loss:
                        # Update the best model and best loss
                        best_loss = val_loss
                        best_model = model
                        best_params = (units, layers, dropout, lr, batch_size)
                        best_history = history

# At the end of the search, 'best_model' contains the model with the lowest validation loss
# 'best_params' holds the parameters that yielded the best model, and 'best_history' contains the training history
# Out:
# Training model with units=50, layers=1, dropout=0.2, lr=0.0001, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.3904 - val_loss: 0.1279 - learning_rate: 1.0000e-04
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1197 - val_loss: 0.0110 - learning_rate: 1.0000e-04
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0434 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0342 - val_loss: 0.0084 - learning_rate: 1.0000e-04
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0274 - val_loss: 0.0091 - learning_rate: 1.0000e-04
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0232 - val_loss: 0.0109 - learning_rate: 1.0000e-04
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0159 - val_loss: 0.0131 - learning_rate: 1.0000e-04
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0134 - val_loss: 0.0146 - learning_rate: 5.0000e-05
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0105 - val_loss: 0.0161 - learning_rate: 5.0000e-05
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0098 - val_loss: 0.0181 - learning_rate: 5.0000e-05
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0089 - val_loss: 0.0191 - learning_rate: 2.5000e-05
# Epoch 12/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0078 - val_loss: 0.0198 - learning_rate: 2.5000e-05
# Epoch 13/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0074 - val_loss: 0.0204 - learning_rate: 2.5000e-05
# Epoch 14/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0063 - val_loss: 0.0209 - learning_rate: 1.2500e-05
# Training model with units=50, layers=1, dropout=0.2, lr=0.0001, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2461 - val_loss: 0.1093 - learning_rate: 1.0000e-04
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1263 - val_loss: 0.0312 - learning_rate: 1.0000e-04
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0595 - val_loss: 0.0073 - learning_rate: 1.0000e-04
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0496 - val_loss: 0.0073 - learning_rate: 1.0000e-04
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0437 - val_loss: 0.0068 - learning_rate: 1.0000e-04
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0361 - val_loss: 0.0063 - learning_rate: 1.0000e-04
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0340 - val_loss: 0.0063 - learning_rate: 1.0000e-04
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0305 - val_loss: 0.0071 - learning_rate: 1.0000e-04
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0265 - val_loss: 0.0083 - learning_rate: 1.0000e-04
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0189 - val_loss: 0.0090 - learning_rate: 5.0000e-05
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0190 - val_loss: 0.0098 - learning_rate: 5.0000e-05
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0176 - val_loss: 0.0111 - learning_rate: 5.0000e-05
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0158 - val_loss: 0.0116 - learning_rate: 2.5000e-05
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0152 - val_loss: 0.0121 - learning_rate: 2.5000e-05
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0147 - val_loss: 0.0128 - learning_rate: 2.5000e-05
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0113 - val_loss: 0.0130 - learning_rate: 1.2500e-05
# Training model with units=50, layers=1, dropout=0.2, lr=0.0001, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2009 - val_loss: 0.1054 - learning_rate: 1.0000e-04
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1247 - val_loss: 0.0543 - learning_rate: 1.0000e-04
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0824 - val_loss: 0.0190 - learning_rate: 1.0000e-04
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0470 - val_loss: 0.0066 - learning_rate: 1.0000e-04
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0489 - val_loss: 0.0058 - learning_rate: 1.0000e-04
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0362 - val_loss: 0.0063 - learning_rate: 1.0000e-04
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0369 - val_loss: 0.0055 - learning_rate: 1.0000e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0394 - val_loss: 0.0052 - learning_rate: 1.0000e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0332 - val_loss: 0.0053 - learning_rate: 1.0000e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0322 - val_loss: 0.0056 - learning_rate: 1.0000e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0255 - val_loss: 0.0062 - learning_rate: 1.0000e-04
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0258 - val_loss: 0.0064 - learning_rate: 5.0000e-05
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0248 - val_loss: 0.0069 - learning_rate: 5.0000e-05
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0206 - val_loss: 0.0074 - learning_rate: 5.0000e-05
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0201 - val_loss: 0.0077 - learning_rate: 2.5000e-05
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0202 - val_loss: 0.0080 - learning_rate: 2.5000e-05
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0191 - val_loss: 0.0084 - learning_rate: 2.5000e-05
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0174 - val_loss: 0.0086 - learning_rate: 1.2500e-05
# Training model with units=50, layers=1, dropout=0.2, lr=0.001, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1586 - val_loss: 0.0125 - learning_rate: 0.0010
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0069 - val_loss: 0.0283 - learning_rate: 0.0010
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0019 - val_loss: 0.0307 - learning_rate: 0.0010
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0014 - val_loss: 0.0304 - learning_rate: 0.0010
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0011 - val_loss: 0.0288 - learning_rate: 5.0000e-04
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0011 - val_loss: 0.0301 - learning_rate: 5.0000e-04
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.8838e-04 - val_loss: 0.0291 - learning_rate: 5.0000e-04
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.6066e-04 - val_loss: 0.0299 - learning_rate: 2.5000e-04
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.7368e-04 - val_loss: 0.0300 - learning_rate: 2.5000e-04
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.8338e-04 - val_loss: 0.0299 - learning_rate: 2.5000e-04
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.2890e-04 - val_loss: 0.0296 - learning_rate: 1.2500e-04
# Training model with units=50, layers=1, dropout=0.2, lr=0.001, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.1919 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0183 - val_loss: 0.0150 - learning_rate: 0.0010
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0075 - val_loss: 0.0263 - learning_rate: 0.0010
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - val_loss: 0.0291 - learning_rate: 0.0010
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024 - val_loss: 0.0295 - learning_rate: 5.0000e-04
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017 - val_loss: 0.0291 - learning_rate: 5.0000e-04
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017 - val_loss: 0.0289 - learning_rate: 5.0000e-04
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - val_loss: 0.0291 - learning_rate: 2.5000e-04
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - val_loss: 0.0287 - learning_rate: 2.5000e-04
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - val_loss: 0.0288 - learning_rate: 2.5000e-04
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - val_loss: 0.0291 - learning_rate: 1.2500e-04
# Training model with units=50, layers=1, dropout=0.2, lr=0.001, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0990 - val_loss: 0.0096 - learning_rate: 0.0010
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0279 - val_loss: 0.0092 - learning_rate: 0.0010
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0119 - val_loss: 0.0260 - learning_rate: 0.0010
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - val_loss: 0.0279 - learning_rate: 0.0010
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0279 - learning_rate: 0.0010
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013 - val_loss: 0.0278 - learning_rate: 5.0000e-04
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0013 - val_loss: 0.0281 - learning_rate: 5.0000e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 0.0279 - learning_rate: 5.0000e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 0.0283 - learning_rate: 2.5000e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012 - val_loss: 0.0286 - learning_rate: 2.5000e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 0.0285 - learning_rate: 2.5000e-04
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - val_loss: 0.0285 - learning_rate: 1.2500e-04
# Training model with units=50, layers=1, dropout=0.2, lr=0.005, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0564 - val_loss: 0.0278 - learning_rate: 0.0050
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.6111e-04 - val_loss: 0.0318 - learning_rate: 0.0050
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.5757e-04 - val_loss: 0.0284 - learning_rate: 0.0050
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.8143e-04 - val_loss: 0.0301 - learning_rate: 0.0050
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.3304e-04 - val_loss: 0.0308 - learning_rate: 0.0025
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7719e-04 - val_loss: 0.0313 - learning_rate: 0.0025
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.9547e-04 - val_loss: 0.0304 - learning_rate: 0.0025
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.2545e-04 - val_loss: 0.0280 - learning_rate: 0.0012
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.9950e-04 - val_loss: 0.0294 - learning_rate: 0.0012
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.0107e-04 - val_loss: 0.0315 - learning_rate: 0.0012
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.0396e-04 - val_loss: 0.0295 - learning_rate: 6.2500e-04
# Training model with units=50, layers=1, dropout=0.2, lr=0.005, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0522 - val_loss: 0.0266 - learning_rate: 0.0050
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - val_loss: 0.0300 - learning_rate: 0.0050
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8783e-04 - val_loss: 0.0284 - learning_rate: 0.0050
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6217e-04 - val_loss: 0.0297 - learning_rate: 0.0050
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4520e-04 - val_loss: 0.0291 - learning_rate: 0.0025
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8280e-04 - val_loss: 0.0302 - learning_rate: 0.0025
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6714e-04 - val_loss: 0.0295 - learning_rate: 0.0025
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0449e-04 - val_loss: 0.0292 - learning_rate: 0.0012
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8972e-04 - val_loss: 0.0308 - learning_rate: 0.0012
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4976e-04 - val_loss: 0.0296 - learning_rate: 0.0012
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6823e-04 - val_loss: 0.0294 - learning_rate: 6.2500e-04
# Training model with units=50, layers=1, dropout=0.2, lr=0.005, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1347 - val_loss: 0.0169 - learning_rate: 0.0050
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0088 - val_loss: 0.0245 - learning_rate: 0.0050
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0288 - learning_rate: 0.0050
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9275e-04 - val_loss: 0.0286 - learning_rate: 0.0050
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.8118e-04 - val_loss: 0.0290 - learning_rate: 0.0025
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0948e-04 - val_loss: 0.0303 - learning_rate: 0.0025
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.3492e-04 - val_loss: 0.0294 - learning_rate: 0.0025
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4996e-04 - val_loss: 0.0297 - learning_rate: 0.0012
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.1578e-04 - val_loss: 0.0294 - learning_rate: 0.0012
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7772e-04 - val_loss: 0.0301 - learning_rate: 0.0012
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.3837e-04 - val_loss: 0.0304 - learning_rate: 6.2500e-04
# Training model with units=50, layers=1, dropout=0.3, lr=0.0001, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.3491 - val_loss: 0.1181 - learning_rate: 1.0000e-04
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1149 - val_loss: 0.0147 - learning_rate: 1.0000e-04
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0515 - val_loss: 0.0105 - learning_rate: 1.0000e-04
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0461 - val_loss: 0.0101 - learning_rate: 1.0000e-04
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0268 - val_loss: 0.0134 - learning_rate: 1.0000e-04
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0173 - val_loss: 0.0188 - learning_rate: 1.0000e-04
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0105 - val_loss: 0.0243 - learning_rate: 1.0000e-04
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0076 - val_loss: 0.0244 - learning_rate: 5.0000e-05
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0062 - val_loss: 0.0260 - learning_rate: 5.0000e-05
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0066 - val_loss: 0.0265 - learning_rate: 5.0000e-05
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0063 - val_loss: 0.0268 - learning_rate: 2.5000e-05
# Epoch 12/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0058 - val_loss: 0.0271 - learning_rate: 2.5000e-05
# Epoch 13/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0051 - val_loss: 0.0276 - learning_rate: 2.5000e-05
# Epoch 14/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0050 - val_loss: 0.0274 - learning_rate: 1.2500e-05
# Training model with units=50, layers=1, dropout=0.3, lr=0.0001, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.3209 - val_loss: 0.1551 - learning_rate: 1.0000e-04
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1722 - val_loss: 0.0618 - learning_rate: 1.0000e-04
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0775 - val_loss: 0.0155 - learning_rate: 1.0000e-04
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0516 - val_loss: 0.0129 - learning_rate: 1.0000e-04
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0553 - val_loss: 0.0113 - learning_rate: 1.0000e-04
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0508 - val_loss: 0.0091 - learning_rate: 1.0000e-04
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0338 - val_loss: 0.0096 - learning_rate: 1.0000e-04
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0264 - val_loss: 0.0114 - learning_rate: 1.0000e-04
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0184 - val_loss: 0.0151 - learning_rate: 1.0000e-04
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0117 - val_loss: 0.0169 - learning_rate: 5.0000e-05
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0095 - val_loss: 0.0192 - learning_rate: 5.0000e-05
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0087 - val_loss: 0.0201 - learning_rate: 5.0000e-05
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076 - val_loss: 0.0209 - learning_rate: 2.5000e-05
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0073 - val_loss: 0.0215 - learning_rate: 2.5000e-05
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072 - val_loss: 0.0220 - learning_rate: 2.5000e-05
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065 - val_loss: 0.0223 - learning_rate: 1.2500e-05
# Training model with units=50, layers=1, dropout=0.3, lr=0.0001, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.3359 - val_loss: 0.1849 - learning_rate: 1.0000e-04
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2175 - val_loss: 0.1140 - learning_rate: 1.0000e-04
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1380 - val_loss: 0.0623 - learning_rate: 1.0000e-04
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0887 - val_loss: 0.0283 - learning_rate: 1.0000e-04
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0717 - val_loss: 0.0144 - learning_rate: 1.0000e-04
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0588 - val_loss: 0.0124 - learning_rate: 1.0000e-04
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0544 - val_loss: 0.0121 - learning_rate: 1.0000e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0553 - val_loss: 0.0102 - learning_rate: 1.0000e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0488 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0369 - val_loss: 0.0088 - learning_rate: 1.0000e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0354 - val_loss: 0.0096 - learning_rate: 1.0000e-04
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0276 - val_loss: 0.0108 - learning_rate: 1.0000e-04
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0235 - val_loss: 0.0129 - learning_rate: 1.0000e-04
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0151 - val_loss: 0.0143 - learning_rate: 5.0000e-05
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0158 - val_loss: 0.0163 - learning_rate: 5.0000e-05
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0126 - val_loss: 0.0180 - learning_rate: 5.0000e-05
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0107 - val_loss: 0.0189 - learning_rate: 2.5000e-05
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0103 - val_loss: 0.0198 - learning_rate: 2.5000e-05
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0086 - val_loss: 0.0202 - learning_rate: 2.5000e-05
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0090 - val_loss: 0.0205 - learning_rate: 1.2500e-05
# Training model with units=50, layers=1, dropout=0.3, lr=0.001, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1288 - val_loss: 0.0264 - learning_rate: 0.0010
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0036 - val_loss: 0.0294 - learning_rate: 0.0010
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0018 - val_loss: 0.0290 - learning_rate: 0.0010
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0014 - val_loss: 0.0303 - learning_rate: 0.0010
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0011 - val_loss: 0.0304 - learning_rate: 5.0000e-04
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0010 - val_loss: 0.0313 - learning_rate: 5.0000e-04
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0010 - val_loss: 0.0302 - learning_rate: 5.0000e-04
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.1496e-04 - val_loss: 0.0295 - learning_rate: 2.5000e-04
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.8426e-04 - val_loss: 0.0299 - learning_rate: 2.5000e-04
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0010 - val_loss: 0.0299 - learning_rate: 2.5000e-04
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.8500e-04 - val_loss: 0.0308 - learning_rate: 1.2500e-04
# Training model with units=50, layers=1, dropout=0.3, lr=0.001, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1735 - val_loss: 0.0105 - learning_rate: 0.0010
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0191 - val_loss: 0.0258 - learning_rate: 0.0010
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - val_loss: 0.0274 - learning_rate: 0.0010
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022 - val_loss: 0.0293 - learning_rate: 0.0010
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - val_loss: 0.0293 - learning_rate: 5.0000e-04
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016 - val_loss: 0.0292 - learning_rate: 5.0000e-04
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - val_loss: 0.0289 - learning_rate: 5.0000e-04
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - val_loss: 0.0292 - learning_rate: 2.5000e-04
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - val_loss: 0.0295 - learning_rate: 2.5000e-04
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - val_loss: 0.0297 - learning_rate: 2.5000e-04
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - val_loss: 0.0291 - learning_rate: 1.2500e-04
# Training model with units=50, layers=1, dropout=0.3, lr=0.001, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.1733 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0401 - val_loss: 0.0096 - learning_rate: 0.0010
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0146 - val_loss: 0.0230 - learning_rate: 0.0010
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - val_loss: 0.0288 - learning_rate: 0.0010
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - val_loss: 0.0284 - learning_rate: 5.0000e-04
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - val_loss: 0.0285 - learning_rate: 5.0000e-04
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017 - val_loss: 0.0285 - learning_rate: 5.0000e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0284 - learning_rate: 2.5000e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - val_loss: 0.0293 - learning_rate: 2.5000e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 0.0288 - learning_rate: 2.5000e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014 - val_loss: 0.0290 - learning_rate: 1.2500e-04
# Training model with units=50, layers=1, dropout=0.3, lr=0.005, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0545 - val_loss: 0.0290 - learning_rate: 0.0050
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.8921e-04 - val_loss: 0.0316 - learning_rate: 0.0050
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.0654e-04 - val_loss: 0.0308 - learning_rate: 0.0050
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.1749e-04 - val_loss: 0.0280 - learning_rate: 0.0050
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.4804e-04 - val_loss: 0.0300 - learning_rate: 0.0050
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.5754e-04 - val_loss: 0.0284 - learning_rate: 0.0050
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.1555e-04 - val_loss: 0.0290 - learning_rate: 0.0050
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.6085e-04 - val_loss: 0.0305 - learning_rate: 0.0025
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7723e-04 - val_loss: 0.0278 - learning_rate: 0.0025
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.6714e-04 - val_loss: 0.0281 - learning_rate: 0.0025
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.1000e-04 - val_loss: 0.0302 - learning_rate: 0.0025
# Epoch 12/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.0142e-04 - val_loss: 0.0289 - learning_rate: 0.0025
# Epoch 13/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.9502e-04 - val_loss: 0.0288 - learning_rate: 0.0012
# Epoch 14/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.3879e-04 - val_loss: 0.0271 - learning_rate: 0.0012
# Epoch 15/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.1942e-04 - val_loss: 0.0292 - learning_rate: 0.0012
# Epoch 16/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.6108e-04 - val_loss: 0.0273 - learning_rate: 0.0012
# Epoch 17/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.2246e-04 - val_loss: 0.0297 - learning_rate: 0.0012
# Epoch 18/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.9513e-04 - val_loss: 0.0277 - learning_rate: 6.2500e-04
# Epoch 19/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4955e-04 - val_loss: 0.0282 - learning_rate: 6.2500e-04
# Epoch 20/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4283e-04 - val_loss: 0.0275 - learning_rate: 6.2500e-04
# Epoch 21/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2381e-04 - val_loss: 0.0284 - learning_rate: 3.1250e-04
# Epoch 22/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.6589e-04 - val_loss: 0.0285 - learning_rate: 3.1250e-04
# Epoch 23/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.3830e-04 - val_loss: 0.0280 - learning_rate: 3.1250e-04
# Epoch 24/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.7625e-04 - val_loss: 0.0278 - learning_rate: 1.5625e-04
# Training model with units=50, layers=1, dropout=0.3, lr=0.005, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0770 - val_loss: 0.0359 - learning_rate: 0.0050
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - val_loss: 0.0299 - learning_rate: 0.0050
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3715e-04 - val_loss: 0.0307 - learning_rate: 0.0050
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9064e-04 - val_loss: 0.0302 - learning_rate: 0.0050
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8924e-04 - val_loss: 0.0299 - learning_rate: 0.0050
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6495e-04 - val_loss: 0.0307 - learning_rate: 0.0025
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.3169e-04 - val_loss: 0.0295 - learning_rate: 0.0025
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0707e-04 - val_loss: 0.0317 - learning_rate: 0.0025
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4324e-04 - val_loss: 0.0302 - learning_rate: 0.0025
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2578e-04 - val_loss: 0.0280 - learning_rate: 0.0025
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0932e-04 - val_loss: 0.0315 - learning_rate: 0.0025
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8540e-04 - val_loss: 0.0301 - learning_rate: 0.0025
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6422e-04 - val_loss: 0.0301 - learning_rate: 0.0025
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9779e-04 - val_loss: 0.0293 - learning_rate: 0.0012
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0012e-04 - val_loss: 0.0297 - learning_rate: 0.0012
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0323e-04 - val_loss: 0.0300 - learning_rate: 0.0012
# Epoch 17/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8858e-04 - val_loss: 0.0302 - learning_rate: 6.2500e-04
# Epoch 18/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7382e-04 - val_loss: 0.0291 - learning_rate: 6.2500e-04
# Epoch 19/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0100e-04 - val_loss: 0.0306 - learning_rate: 6.2500e-04
# Epoch 20/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2089e-04 - val_loss: 0.0298 - learning_rate: 3.1250e-04
# Training model with units=50, layers=1, dropout=0.3, lr=0.005, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0861 - val_loss: 0.0243 - learning_rate: 0.0050
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - val_loss: 0.0283 - learning_rate: 0.0050
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.5740e-04 - val_loss: 0.0302 - learning_rate: 0.0050
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.2624e-04 - val_loss: 0.0300 - learning_rate: 0.0050
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.1376e-04 - val_loss: 0.0309 - learning_rate: 0.0025
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7648e-04 - val_loss: 0.0306 - learning_rate: 0.0025
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1944e-04 - val_loss: 0.0304 - learning_rate: 0.0025
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.2871e-04 - val_loss: 0.0302 - learning_rate: 0.0012
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6855e-04 - val_loss: 0.0299 - learning_rate: 0.0012
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.3385e-04 - val_loss: 0.0298 - learning_rate: 0.0012
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.5149e-04 - val_loss: 0.0300 - learning_rate: 6.2500e-04
# Training model with units=50, layers=1, dropout=0.5, lr=0.0001, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.2189 - val_loss: 0.0479 - learning_rate: 1.0000e-04
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1133 - val_loss: 0.0162 - learning_rate: 1.0000e-04
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0659 - val_loss: 0.0135 - learning_rate: 1.0000e-04
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0221 - val_loss: 0.0268 - learning_rate: 1.0000e-04
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0098 - val_loss: 0.0265 - learning_rate: 1.0000e-04
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0077 - val_loss: 0.0285 - learning_rate: 1.0000e-04
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0075 - val_loss: 0.0279 - learning_rate: 5.0000e-05
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0056 - val_loss: 0.0277 - learning_rate: 5.0000e-05
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0056 - val_loss: 0.0282 - learning_rate: 5.0000e-05
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0055 - val_loss: 0.0282 - learning_rate: 2.5000e-05
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0049 - val_loss: 0.0292 - learning_rate: 2.5000e-05
# Epoch 12/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0049 - val_loss: 0.0287 - learning_rate: 2.5000e-05
# Epoch 13/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0047 - val_loss: 0.0292 - learning_rate: 1.2500e-05
# Training model with units=50, layers=1, dropout=0.5, lr=0.0001, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1578 - val_loss: 0.0388 - learning_rate: 1.0000e-04
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1355 - val_loss: 0.0307 - learning_rate: 1.0000e-04
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1022 - val_loss: 0.0179 - learning_rate: 1.0000e-04
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0693 - val_loss: 0.0128 - learning_rate: 1.0000e-04
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0223 - val_loss: 0.0252 - learning_rate: 1.0000e-04
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0127 - val_loss: 0.0234 - learning_rate: 1.0000e-04
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0104 - val_loss: 0.0250 - learning_rate: 1.0000e-04
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0096 - val_loss: 0.0257 - learning_rate: 5.0000e-05
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0090 - val_loss: 0.0243 - learning_rate: 5.0000e-05
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0090 - val_loss: 0.0252 - learning_rate: 5.0000e-05
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0081 - val_loss: 0.0253 - learning_rate: 2.5000e-05
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0073 - val_loss: 0.0259 - learning_rate: 2.5000e-05
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - val_loss: 0.0251 - learning_rate: 2.5000e-05
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065 - val_loss: 0.0253 - learning_rate: 1.2500e-05
# Training model with units=50, layers=1, dropout=0.5, lr=0.0001, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.3738 - val_loss: 0.2233 - learning_rate: 1.0000e-04
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2646 - val_loss: 0.1535 - learning_rate: 1.0000e-04
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1853 - val_loss: 0.0970 - learning_rate: 1.0000e-04
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1321 - val_loss: 0.0541 - learning_rate: 1.0000e-04
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1064 - val_loss: 0.0291 - learning_rate: 1.0000e-04
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0909 - val_loss: 0.0195 - learning_rate: 1.0000e-04
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0771 - val_loss: 0.0136 - learning_rate: 1.0000e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0620 - val_loss: 0.0114 - learning_rate: 1.0000e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0443 - val_loss: 0.0125 - learning_rate: 1.0000e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0308 - val_loss: 0.0172 - learning_rate: 1.0000e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0184 - val_loss: 0.0220 - learning_rate: 1.0000e-04
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0133 - val_loss: 0.0235 - learning_rate: 5.0000e-05
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0125 - val_loss: 0.0240 - learning_rate: 5.0000e-05
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0123 - val_loss: 0.0247 - learning_rate: 5.0000e-05
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0104 - val_loss: 0.0248 - learning_rate: 2.5000e-05
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0104 - val_loss: 0.0252 - learning_rate: 2.5000e-05
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0107 - val_loss: 0.0257 - learning_rate: 2.5000e-05
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0106 - val_loss: 0.0258 - learning_rate: 1.2500e-05
# Training model with units=50, layers=1, dropout=0.5, lr=0.001, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0750 - val_loss: 0.0295 - learning_rate: 0.0010
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0018 - val_loss: 0.0300 - learning_rate: 0.0010
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0014 - val_loss: 0.0294 - learning_rate: 0.0010
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0010 - val_loss: 0.0306 - learning_rate: 0.0010
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.9887e-04 - val_loss: 0.0309 - learning_rate: 0.0010
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.7641e-04 - val_loss: 0.0284 - learning_rate: 0.0010
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.0367e-04 - val_loss: 0.0297 - learning_rate: 0.0010
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.3307e-04 - val_loss: 0.0282 - learning_rate: 0.0010
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.1519e-04 - val_loss: 0.0305 - learning_rate: 0.0010
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.8549e-04 - val_loss: 0.0292 - learning_rate: 0.0010
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.5563e-04 - val_loss: 0.0286 - learning_rate: 0.0010
# Epoch 12/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.6531e-04 - val_loss: 0.0280 - learning_rate: 5.0000e-04
# Epoch 13/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.7975e-04 - val_loss: 0.0272 - learning_rate: 5.0000e-04
# Epoch 14/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.3056e-04 - val_loss: 0.0280 - learning_rate: 5.0000e-04
# Epoch 15/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4768e-04 - val_loss: 0.0271 - learning_rate: 5.0000e-04
# Epoch 16/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.6617e-04 - val_loss: 0.0276 - learning_rate: 5.0000e-04
# Epoch 17/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.7697e-04 - val_loss: 0.0281 - learning_rate: 2.5000e-04
# Epoch 18/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.8555e-04 - val_loss: 0.0275 - learning_rate: 2.5000e-04
# Epoch 19/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.5879e-04 - val_loss: 0.0273 - learning_rate: 2.5000e-04
# Epoch 20/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4848e-04 - val_loss: 0.0275 - learning_rate: 1.2500e-04
# Epoch 21/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.6045e-04 - val_loss: 0.0282 - learning_rate: 1.2500e-04
# Epoch 22/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.1620e-04 - val_loss: 0.0275 - learning_rate: 1.2500e-04
# Epoch 23/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2708e-04 - val_loss: 0.0280 - learning_rate: 6.2500e-05
# Epoch 24/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2226e-04 - val_loss: 0.0277 - learning_rate: 6.2500e-05
# Epoch 25/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.3242e-04 - val_loss: 0.0274 - learning_rate: 6.2500e-05
# Training model with units=50, layers=1, dropout=0.5, lr=0.001, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.2462 - val_loss: 0.0135 - learning_rate: 0.0010
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0172 - val_loss: 0.0318 - learning_rate: 0.0010
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - val_loss: 0.0309 - learning_rate: 0.0010
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024 - val_loss: 0.0288 - learning_rate: 0.0010
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018 - val_loss: 0.0297 - learning_rate: 5.0000e-04
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016 - val_loss: 0.0307 - learning_rate: 5.0000e-04
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017 - val_loss: 0.0310 - learning_rate: 5.0000e-04
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - val_loss: 0.0309 - learning_rate: 2.5000e-04
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - val_loss: 0.0310 - learning_rate: 2.5000e-04
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - val_loss: 0.0305 - learning_rate: 2.5000e-04
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0013 - val_loss: 0.0307 - learning_rate: 1.2500e-04
# Training model with units=50, layers=1, dropout=0.5, lr=0.001, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.2229 - val_loss: 0.0144 - learning_rate: 0.0010
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0345 - val_loss: 0.0311 - learning_rate: 0.0010
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061 - val_loss: 0.0287 - learning_rate: 0.0010
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - val_loss: 0.0298 - learning_rate: 0.0010
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026 - val_loss: 0.0279 - learning_rate: 5.0000e-04
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0291 - learning_rate: 5.0000e-04
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025 - val_loss: 0.0295 - learning_rate: 5.0000e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021 - val_loss: 0.0283 - learning_rate: 2.5000e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018 - val_loss: 0.0293 - learning_rate: 2.5000e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - val_loss: 0.0288 - learning_rate: 2.5000e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019 - val_loss: 0.0297 - learning_rate: 1.2500e-04
# Training model with units=50, layers=1, dropout=0.5, lr=0.005, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0554 - val_loss: 0.0316 - learning_rate: 0.0050
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.8896e-04 - val_loss: 0.0302 - learning_rate: 0.0050
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.6201e-04 - val_loss: 0.0297 - learning_rate: 0.0050
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.9019e-04 - val_loss: 0.0309 - learning_rate: 0.0050
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.4518e-04 - val_loss: 0.0294 - learning_rate: 0.0050
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.3572e-04 - val_loss: 0.0282 - learning_rate: 0.0050
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.9803e-04 - val_loss: 0.0290 - learning_rate: 0.0050
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.8694e-04 - val_loss: 0.0300 - learning_rate: 0.0050
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.7835e-04 - val_loss: 0.0297 - learning_rate: 0.0050
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.9509e-04 - val_loss: 0.0287 - learning_rate: 0.0025
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.4322e-04 - val_loss: 0.0292 - learning_rate: 0.0025
# Epoch 12/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.8728e-04 - val_loss: 0.0286 - learning_rate: 0.0025
# Epoch 13/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.0458e-04 - val_loss: 0.0295 - learning_rate: 0.0012
# Epoch 14/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.5894e-04 - val_loss: 0.0289 - learning_rate: 0.0012
# Epoch 15/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2734e-04 - val_loss: 0.0289 - learning_rate: 0.0012
# Epoch 16/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.5998e-04 - val_loss: 0.0283 - learning_rate: 6.2500e-04
# Training model with units=50, layers=1, dropout=0.5, lr=0.005, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0826 - val_loss: 0.0271 - learning_rate: 0.0050
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - val_loss: 0.0306 - learning_rate: 0.0050
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2428e-04 - val_loss: 0.0308 - learning_rate: 0.0050
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2115e-04 - val_loss: 0.0308 - learning_rate: 0.0050
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1800e-04 - val_loss: 0.0302 - learning_rate: 0.0025
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8923e-04 - val_loss: 0.0312 - learning_rate: 0.0025
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.9838e-04 - val_loss: 0.0302 - learning_rate: 0.0025
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7989e-04 - val_loss: 0.0308 - learning_rate: 0.0012
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0790e-04 - val_loss: 0.0301 - learning_rate: 0.0012
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8908e-04 - val_loss: 0.0295 - learning_rate: 0.0012
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0413e-04 - val_loss: 0.0302 - learning_rate: 6.2500e-04
# Training model with units=50, layers=1, dropout=0.5, lr=0.005, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0972 - val_loss: 0.0272 - learning_rate: 0.0050
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029 - val_loss: 0.0310 - learning_rate: 0.0050
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.9126e-04 - val_loss: 0.0303 - learning_rate: 0.0050
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.6263e-04 - val_loss: 0.0299 - learning_rate: 0.0050
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4522e-04 - val_loss: 0.0301 - learning_rate: 0.0025
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9355e-04 - val_loss: 0.0307 - learning_rate: 0.0025
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.3678e-04 - val_loss: 0.0312 - learning_rate: 0.0025
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0425e-04 - val_loss: 0.0308 - learning_rate: 0.0012
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.5680e-04 - val_loss: 0.0305 - learning_rate: 0.0012
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.3446e-04 - val_loss: 0.0300 - learning_rate: 0.0012
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4672e-04 - val_loss: 0.0307 - learning_rate: 6.2500e-04
# Training model with units=50, layers=2, dropout=0.2, lr=0.0001, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.2405 - val_loss: 0.0050 - learning_rate: 1.0000e-04
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0414 - val_loss: 0.0071 - learning_rate: 1.0000e-04
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0287 - val_loss: 0.0110 - learning_rate: 1.0000e-04
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0162 - val_loss: 0.0153 - learning_rate: 1.0000e-04
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0125 - val_loss: 0.0189 - learning_rate: 5.0000e-05
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0098 - val_loss: 0.0222 - learning_rate: 5.0000e-05
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0064 - val_loss: 0.0244 - learning_rate: 5.0000e-05
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0062 - val_loss: 0.0259 - learning_rate: 2.5000e-05
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0054 - val_loss: 0.0272 - learning_rate: 2.5000e-05
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0056 - val_loss: 0.0277 - learning_rate: 2.5000e-05
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0051 - val_loss: 0.0281 - learning_rate: 1.2500e-05
# Training model with units=50, layers=2, dropout=0.2, lr=0.0001, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.2564 - val_loss: 0.0712 - learning_rate: 1.0000e-04
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0699 - val_loss: 0.0050 - learning_rate: 1.0000e-04
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0467 - val_loss: 0.0067 - learning_rate: 1.0000e-04
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0405 - val_loss: 0.0061 - learning_rate: 1.0000e-04
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0359 - val_loss: 0.0073 - learning_rate: 1.0000e-04
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0269 - val_loss: 0.0081 - learning_rate: 5.0000e-05
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0254 - val_loss: 0.0093 - learning_rate: 5.0000e-05
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0211 - val_loss: 0.0110 - learning_rate: 5.0000e-05
# Epoch 9/100
# ...
# Training model with units=150, layers=3, dropout=0.3, lr=0.005, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.2754 - val_loss: 0.0328 - learning_rate: 0.0050
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0033 - val_loss: 0.0271 - learning_rate: 0.0050
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0016 - val_loss: 0.0319 - learning_rate: 0.0050
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0012 - val_loss: 0.0316 - learning_rate: 0.0050
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0011 - val_loss: 0.0306 - learning_rate: 0.0050
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0011 - val_loss: 0.0312 - learning_rate: 0.0025
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 9.5679e-04 - val_loss: 0.0310 - learning_rate: 0.0025
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 9.3066e-04 - val_loss: 0.0305 - learning_rate: 0.0025
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 9.4915e-04 - val_loss: 0.0310 - learning_rate: 0.0012
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0010 - val_loss: 0.0312 - learning_rate: 0.0012
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 9.9136e-04 - val_loss: 0.0305 - learning_rate: 0.0012
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0011 - val_loss: 0.0302 - learning_rate: 6.2500e-04
# Training model with units=150, layers=3, dropout=0.5, lr=0.0001, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - loss: 0.1825 - val_loss: 0.0131 - learning_rate: 1.0000e-04
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0198 - val_loss: 0.0287 - learning_rate: 1.0000e-04
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0074 - val_loss: 0.0316 - learning_rate: 1.0000e-04
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0048 - val_loss: 0.0314 - learning_rate: 1.0000e-04
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0042 - val_loss: 0.0290 - learning_rate: 5.0000e-05
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0037 - val_loss: 0.0307 - learning_rate: 5.0000e-05
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0030 - val_loss: 0.0306 - learning_rate: 5.0000e-05
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0027 - val_loss: 0.0317 - learning_rate: 2.5000e-05
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0028 - val_loss: 0.0309 - learning_rate: 2.5000e-05
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0022 - val_loss: 0.0308 - learning_rate: 2.5000e-05
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0024 - val_loss: 0.0308 - learning_rate: 1.2500e-05
# Training model with units=150, layers=3, dropout=0.5, lr=0.0001, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - loss: 0.1997 - val_loss: 0.0290 - learning_rate: 1.0000e-04
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0806 - val_loss: 0.0160 - learning_rate: 1.0000e-04
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0167 - val_loss: 0.0328 - learning_rate: 1.0000e-04
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0088 - val_loss: 0.0321 - learning_rate: 1.0000e-04
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0076 - val_loss: 0.0276 - learning_rate: 1.0000e-04
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0060 - val_loss: 0.0293 - learning_rate: 5.0000e-05
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0050 - val_loss: 0.0303 - learning_rate: 5.0000e-05
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0047 - val_loss: 0.0284 - learning_rate: 5.0000e-05
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 0.0046 - val_loss: 0.0295 - learning_rate: 2.5000e-05
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0044 - val_loss: 0.0307 - learning_rate: 2.5000e-05
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0039 - val_loss: 0.0294 - learning_rate: 2.5000e-05
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0045 - val_loss: 0.0309 - learning_rate: 1.2500e-05
# Training model with units=150, layers=3, dropout=0.5, lr=0.0001, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - loss: 0.2154 - val_loss: 0.0188 - learning_rate: 1.0000e-04
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.1097 - val_loss: 0.0160 - learning_rate: 1.0000e-04
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0602 - val_loss: 0.0165 - learning_rate: 1.0000e-04
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0166 - val_loss: 0.0321 - learning_rate: 1.0000e-04
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0102 - val_loss: 0.0290 - learning_rate: 1.0000e-04
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0078 - val_loss: 0.0281 - learning_rate: 5.0000e-05
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.0076 - val_loss: 0.0308 - learning_rate: 5.0000e-05
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0061 - val_loss: 0.0287 - learning_rate: 5.0000e-05
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0059 - val_loss: 0.0293 - learning_rate: 2.5000e-05
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0055 - val_loss: 0.0293 - learning_rate: 2.5000e-05
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0049 - val_loss: 0.0303 - learning_rate: 2.5000e-05
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 0.0051 - val_loss: 0.0299 - learning_rate: 1.2500e-05
# Training model with units=150, layers=3, dropout=0.5, lr=0.001, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 0.0686 - val_loss: 0.0339 - learning_rate: 0.0010
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0019 - val_loss: 0.0331 - learning_rate: 0.0010
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0013 - val_loss: 0.0324 - learning_rate: 0.0010
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0010 - val_loss: 0.0282 - learning_rate: 0.0010
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0011 - val_loss: 0.0328 - learning_rate: 0.0010
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0011 - val_loss: 0.0292 - learning_rate: 0.0010
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0011 - val_loss: 0.0321 - learning_rate: 0.0010
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - loss: 8.7267e-04 - val_loss: 0.0305 - learning_rate: 5.0000e-04
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 9.3968e-04 - val_loss: 0.0321 - learning_rate: 5.0000e-04
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 9.2682e-04 - val_loss: 0.0296 - learning_rate: 5.0000e-04
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 9.0950e-04 - val_loss: 0.0314 - learning_rate: 2.5000e-04
# Epoch 12/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 8.6365e-04 - val_loss: 0.0315 - learning_rate: 2.5000e-04
# Epoch 13/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 9.5941e-04 - val_loss: 0.0313 - learning_rate: 2.5000e-04
# Epoch 14/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 7.9834e-04 - val_loss: 0.0319 - learning_rate: 1.2500e-04
# Training model with units=150, layers=3, dropout=0.5, lr=0.001, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 13s 65ms/step - loss: 0.1111 - val_loss: 0.0321 - learning_rate: 0.0010
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0033 - val_loss: 0.0289 - learning_rate: 0.0010
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0018 - val_loss: 0.0308 - learning_rate: 0.0010
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0014 - val_loss: 0.0312 - learning_rate: 0.0010
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0011 - val_loss: 0.0324 - learning_rate: 0.0010
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 9.8763e-04 - val_loss: 0.0312 - learning_rate: 5.0000e-04
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 9.4591e-04 - val_loss: 0.0310 - learning_rate: 5.0000e-04
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 9.0305e-04 - val_loss: 0.0308 - learning_rate: 5.0000e-04
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 8.9266e-04 - val_loss: 0.0306 - learning_rate: 2.5000e-04
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 8.4751e-04 - val_loss: 0.0304 - learning_rate: 2.5000e-04
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 8.5997e-04 - val_loss: 0.0325 - learning_rate: 2.5000e-04
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 8.4024e-04 - val_loss: 0.0307 - learning_rate: 1.2500e-04
# Training model with units=150, layers=3, dropout=0.5, lr=0.001, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 0.1148 - val_loss: 0.0302 - learning_rate: 0.0010
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 0.0033 - val_loss: 0.0330 - learning_rate: 0.0010
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0017 - val_loss: 0.0326 - learning_rate: 0.0010
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0014 - val_loss: 0.0302 - learning_rate: 0.0010
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0012 - val_loss: 0.0296 - learning_rate: 5.0000e-04
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0011 - val_loss: 0.0315 - learning_rate: 5.0000e-04
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 9.4583e-04 - val_loss: 0.0306 - learning_rate: 5.0000e-04
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 9.6045e-04 - val_loss: 0.0359 - learning_rate: 5.0000e-04
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0011 - val_loss: 0.0319 - learning_rate: 2.5000e-04
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 8.7642e-04 - val_loss: 0.0319 - learning_rate: 2.5000e-04
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 8.1505e-04 - val_loss: 0.0315 - learning_rate: 2.5000e-04
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 8.6491e-04 - val_loss: 0.0313 - learning_rate: 1.2500e-04
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 9.6789e-04 - val_loss: 0.0326 - learning_rate: 1.2500e-04
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 7.9607e-04 - val_loss: 0.0314 - learning_rate: 1.2500e-04
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 7.9521e-04 - val_loss: 0.0312 - learning_rate: 6.2500e-05
# Training model with units=150, layers=3, dropout=0.5, lr=0.005, batch_size=16
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 7s 45ms/step - loss: 0.0904 - val_loss: 0.0288 - learning_rate: 0.0050
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0014 - val_loss: 0.0306 - learning_rate: 0.0050
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 9.8943e-04 - val_loss: 0.0302 - learning_rate: 0.0050
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0013 - val_loss: 0.0291 - learning_rate: 0.0050
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 9.6652e-04 - val_loss: 0.0307 - learning_rate: 0.0025
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 9.4848e-04 - val_loss: 0.0320 - learning_rate: 0.0025
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 8.8097e-04 - val_loss: 0.0299 - learning_rate: 0.0025
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 8.9538e-04 - val_loss: 0.0306 - learning_rate: 0.0012
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 9.4730e-04 - val_loss: 0.0325 - learning_rate: 0.0012
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 8.0051e-04 - val_loss: 0.0314 - learning_rate: 0.0012
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 9.4656e-04 - val_loss: 0.0310 - learning_rate: 6.2500e-04
# Training model with units=150, layers=3, dropout=0.5, lr=0.005, batch_size=32
# Epoch 1/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - loss: 0.1579 - val_loss: 0.0317 - learning_rate: 0.0050
# Epoch 2/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0022 - val_loss: 0.0300 - learning_rate: 0.0050
# Epoch 3/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0014 - val_loss: 0.0303 - learning_rate: 0.0050
# Epoch 4/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0012 - val_loss: 0.0303 - learning_rate: 0.0050
# Epoch 5/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0010 - val_loss: 0.0298 - learning_rate: 0.0050
# Epoch 6/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0010 - val_loss: 0.0298 - learning_rate: 0.0050
# Epoch 7/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0010 - val_loss: 0.0292 - learning_rate: 0.0050
# Epoch 8/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0012 - val_loss: 0.0294 - learning_rate: 0.0050
# Epoch 9/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0010 - val_loss: 0.0312 - learning_rate: 0.0050
# Epoch 10/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0010 - val_loss: 0.0304 - learning_rate: 0.0050
# Epoch 11/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 8.7251e-04 - val_loss: 0.0303 - learning_rate: 0.0025
# Epoch 12/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 7.7135e-04 - val_loss: 0.0305 - learning_rate: 0.0025
# Epoch 13/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 8.7208e-04 - val_loss: 0.0296 - learning_rate: 0.0025
# Epoch 14/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 8.9704e-04 - val_loss: 0.0302 - learning_rate: 0.0012
# Epoch 15/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 8.3436e-04 - val_loss: 0.0318 - learning_rate: 0.0012
# Epoch 16/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 7.6948e-04 - val_loss: 0.0318 - learning_rate: 0.0012
# Epoch 17/100
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 8.1791e-04 - val_loss: 0.0320 - learning_rate: 6.2500e-04
# Training model with units=150, layers=3, dropout=0.5, lr=0.005, batch_size=48
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - loss: 0.1955 - val_loss: 0.0349 - learning_rate: 0.0050
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.0033 - val_loss: 0.0328 - learning_rate: 0.0050
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.0016 - val_loss: 0.0303 - learning_rate: 0.0050
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 0.0013 - val_loss: 0.0312 - learning_rate: 0.0050
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0011 - val_loss: 0.0297 - learning_rate: 0.0050
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0011 - val_loss: 0.0310 - learning_rate: 0.0050
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0011 - val_loss: 0.0293 - learning_rate: 0.0050
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0011 - val_loss: 0.0296 - learning_rate: 0.0050
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0011 - val_loss: 0.0311 - learning_rate: 0.0050
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - loss: 0.0010 - val_loss: 0.0308 - learning_rate: 0.0050
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 0.0010 - val_loss: 0.0297 - learning_rate: 0.0025
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 9.1807e-04 - val_loss: 0.0314 - learning_rate: 0.0025
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 8.9669e-04 - val_loss: 0.0306 - learning_rate: 0.0025
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 8.6836e-04 - val_loss: 0.0307 - learning_rate: 0.0012
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 8.5237e-04 - val_loss: 0.0315 - learning_rate: 0.0012
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 8.4286e-04 - val_loss: 0.0306 - learning_rate: 0.0012
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 8.1784e-04 - val_loss: 0.0306 - learning_rate: 6.2500e-04

# %%
# Plot the training history of the best model
# Plot the loss and validation loss over epochs for the best model
plt.plot(best_history.history['loss'], label='Train Loss')
plt.plot(best_history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Output the best model parameters
# Print the best hyperparameters found in the grid search
print(f"Best model parameters: Units={best_params[0]}, Layers={best_params[1]}, Dropout={best_params[2]}, Learning Rate={best_params[3]}, Batch Size={best_params[4]}")
# Out:
# Best model parameters: Units=100, Layers=2, Dropout=0.2, Learning Rate=0.0001, Batch Size=32

# %%
#best_model.save('LL Prediction 1.h5')

# %% [markdown]
# ### Testing Part

# %% [markdown]
# #### 1) Load the model

# %%
best_model
# Out:
# <Sequential name=sequential_110, built=True>

# %% [markdown]
# #### 2) Window sampling for testing set

# %%
import numpy as np

# Parameters for window sampling
input_window_size = 28
output_window_size = 1
stride = 1

# Initialize lists to store the input (X_test) and output (y_test) sequences for testing set
X_test, y_test = [], []

# Loop through the testing set to create windows of input and output sequences
for i in range(0, len(testing_set) - input_window_size - output_window_size + 1, stride):
    # Define the input window (20 data points)
    input_window = testing_set.iloc[i:i+input_window_size][['Latitude']]
    # Define the output window (1 data point immediately following the input window)
    output_window = testing_set.iloc[i+input_window_size:i+input_window_size+output_window_size][['Latitude']]
    # Append the input window to X_test and the last value of output window to y_test
    X_test.append(input_window.values)
    y_test.append(output_window.values[-1])

# Convert X_test and y_test lists to numpy arrays for model input
X_test, y_test = np.array(X_test), np.array(y_test)

# Print the number of samples created for testing
print(f"Number of test samples: {X_test.shape[0]}")
print(f"Test input shape: {X_test.shape}, Test target shape: {y_test.shape}")
# Out:
# Number of test samples: 648
# Test input shape: (648, 28, 1), Test target shape: (648, 1)

# %% [markdown]
# #### 3) Test the Testing Set Using the Imported Model

# %%
best_model
# Out:
# <Sequential name=sequential_110, built=True>

# %%
# Make predictions on the testing set
y_pred = best_model.predict(X_test)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step

# %% [markdown]
# #### 4) Calculate Error on the Testing Set

# %%
y_test
# Out:
# array([[0.72558625],
#        [0.72657459],
#        [0.72963532],
#        [0.73151199],
#        [0.73033511],
#        [0.72818631],
#        [0.72670491],
#        [0.72576318],
#        [0.72576338],
#        [0.72576337],
#        [0.72576342],
#        [0.72576358],
#        [0.72576253],
#        [0.72631554],
#        [0.72887283],
#        [0.74114104],
#        [0.7488761 ],
#        [0.75656808],
#        [0.76921204],
#        [0.77696776],
#        [0.78102901],
#        [0.78571715],
#        [0.78852959],
#        [0.79065314],
#        [0.79730607],
#        [0.80505564],
#        [0.81195722],
#        [0.82089809],
#        [0.82886427],
#        [0.83810245],
#        [0.84274481],
#        [0.85046184],
#        [0.85937814],
#        [0.86253028],
#        [0.86689806],
#        [0.8751615 ],
#        [0.88561521],
#        [0.89602931],
#        [0.90758665],
#        [0.91451102],
#        [0.92664169],
#        [0.93359652],
#        [0.94114814],
#        [0.9507044 ],
#        [0.95704071],
#        [0.96354469],
#        [0.96932753],
#        [0.97545952],
#        [0.98105532],
#        [0.98436225],
#        [0.98679198],
#        [0.9871311 ],
#        [0.98526845],
#        [0.98171388],
#        [0.97700162],
#        [0.97184982],
#        [0.97178709],
#        [0.97253138],
#        [0.97342848],
#        [0.97268115],
#        [0.97243585],
#        [0.97129304],
#        [0.9643398 ],
#        [0.96369636],
#        [0.96370235],
#        [0.96370996],
#        [0.96371875],
#        [0.96370554],
#        [0.96368424],
#        [0.96369078],
#        [0.96370281],
#        [0.96371456],
#        [0.96370328],
#        [0.96400573],
#        [0.96430818],
#        [0.96461063],
#        [0.96491308],
#        [0.96521553],
#        [0.96551798],
#        [0.97320582],
#        [0.98208966],
#        [0.98688731],
#        [0.98744588],
#        [0.98353294],
#        [0.9766615 ],
#        [0.96816939],
#        [0.96037898],
#        [0.95320871],
#        [0.94093452],
#        [0.93028653],
#        [0.91873   ],
#        [0.91041808],
#        [0.89846237],
#        [0.8881942 ],
#        [0.87704438],
#        [0.86559188],
#        [0.85492485],
#        [0.84197811],
#        [0.83289161],
#        [0.82309736],
#        [0.81158383],
#        [0.80303778],
#        [0.79577106],
#        [0.79092896],
#        [0.78821805],
#        [0.78499249],
#        [0.78163754],
#        [0.77582192],
#        [0.76935135],
#        [0.76206626],
#        [0.75149474],
#        [0.74258764],
#        [0.73705122],
#        [0.73042326],
#        [0.72352791],
#        [0.7159166 ],
#        [0.70809574],
#        [0.69764065],
#        [0.6886496 ],
#        [0.67783939],
#        [0.66601918],
#        [0.66193159],
#        [0.65689731],
#        [0.65750659],
#        [0.65947653],
#        [0.66120214],
#        [0.66419988],
#        [0.66633934],
#        [0.66879042],
#        [0.67029402],
#        [0.67136698],
#        [0.67331389],
#        [0.6727147 ],
#        [0.67002546],
#        [0.66622253],
#        [0.66193505],
#        [0.65850441],
#        [0.65435841],
#        [0.65140694],
#        [0.64759756],
#        [0.64396194],
#        [0.64093442],
#        [0.63580639],
#        [0.63297383],
#        [0.62837352],
#        [0.62535094],
#        [0.62168292],
#        [0.61934467],
#        [0.61674584],
#        [0.61538506],
#        [0.61538462],
#        [0.61538499],
#        [0.61508417],
#        [0.6119127 ],
#        [0.60212919],
#        [0.59290403],
#        [0.58263418],
#        [0.57303325],
#        [0.56396063],
#        [0.55364209],
#        [0.54323077],
#        [0.53070024],
#        [0.52092993],
#        [0.51053964],
#        [0.49861505],
#        [0.4886478 ],
#        [0.4804081 ],
#        [0.47132431],
#        [0.46175227],
#        [0.45132253],
#        [0.44234265],
#        [0.43789304],
#        [0.43445604],
#        [0.4380588 ],
#        [0.44180123],
#        [0.44508044],
#        [0.4493042 ],
#        [0.45222035],
#        [0.45589023],
#        [0.45363288],
#        [0.45037104],
#        [0.44727061],
#        [0.44376041],
#        [0.44022667],
#        [0.43706123],
#        [0.43371577],
#        [0.43183607],
#        [0.4282174 ],
#        [0.42551593],
#        [0.42172674],
#        [0.4188573 ],
#        [0.41668206],
#        [0.41382047],
#        [0.4100974 ],
#        [0.40409974],
#        [0.39968531],
#        [0.39533435],
#        [0.39136703],
#        [0.38617796],
#        [0.38101138],
#        [0.37853941],
#        [0.37747053],
#        [0.37794043],
#        [0.37838409],
#        [0.3789102 ],
#        [0.37939194],
#        [0.37983149],
#        [0.3803575 ],
#        [0.38082646],
#        [0.38137673],
#        [0.38186589],
#        [0.38239289],
#        [0.38227054],
#        [0.38017653],
#        [0.37762962],
#        [0.36917814],
#        [0.3599186 ],
#        [0.35131775],
#        [0.34512673],
#        [0.33922966],
#        [0.33517056],
#        [0.3369228 ],
#        [0.34852073],
#        [0.36021569],
#        [0.36979952],
#        [0.37711346],
#        [0.3852503 ],
#        [0.39436267],
#        [0.40473215],
#        [0.41523812],
#        [0.42823205],
#        [0.43719104],
#        [0.45144817],
#        [0.46093967],
#        [0.47092394],
#        [0.48291286],
#        [0.49340575],
#        [0.50575586],
#        [0.51807633],
#        [0.52653039],
#        [0.53128936],
#        [0.53190168],
#        [0.53190324],
#        [0.5319116 ],
#        [0.53259058],
#        [0.53404938],
#        [0.53413158],
#        [0.53413219],
#        [0.53413201],
#        [0.53413214],
#        [0.53413219],
#        [0.53413215],
#        [0.53367299],
#        [0.52854727],
#        [0.51509898],
#        [0.50393332],
#        [0.4958189 ],
#        [0.48702366],
#        [0.4715808 ],
#        [0.45726929],
#        [0.44642884],
#        [0.4350942 ],
#        [0.42682646],
#        [0.41574951],
#        [0.40631279],
#        [0.39674076],
#        [0.38603345],
#        [0.37884545],
#        [0.36971709],
#        [0.3623336 ],
#        [0.35092662],
#        [0.34074817],
#        [0.33600641],
#        [0.33563928],
#        [0.33561014],
#        [0.33550765],
#        [0.34182102],
#        [0.34733749],
#        [0.35262975],
#        [0.36274985],
#        [0.3695536 ],
#        [0.37823292],
#        [0.38066724],
#        [0.38219143],
#        [0.38323884],
#        [0.38275508],
#        [0.38226583],
#        [0.38186652],
#        [0.38149737],
#        [0.38093232],
#        [0.38073997],
#        [0.38023727],
#        [0.37980406],
#        [0.37950151],
#        [0.37915361],
#        [0.37867917],
#        [0.37836433],
#        [0.37850729],
#        [0.38077049],
#        [0.38611029],
#        [0.38952814],
#        [0.39379757],
#        [0.39758199],
#        [0.4022176 ],
#        [0.40644999],
#        [0.41215872],
#        [0.42264942],
#        [0.4278598 ],
#        [0.43990854],
#        [0.44823769],
#        [0.45461076],
#        [0.46691449],
#        [0.47598741],
#        [0.48278722],
#        [0.49121262],
#        [0.50060269],
#        [0.50899169],
#        [0.51685398],
#        [0.52680041],
#        [0.53466827],
#        [0.54281757],
#        [0.54776535],
#        [0.5515792 ],
#        [0.5553662 ],
#        [0.55766172],
#        [0.55769912],
#        [0.55771337],
#        [0.55772927],
#        [0.55770149],
#        [0.55770161],
#        [0.55772696],
#        [0.55773584],
#        [0.55770887],
#        [0.55770604],
#        [0.55773235],
#        [0.55773498],
#        [0.5577072 ],
#        [0.55912977],
#        [0.56671161],
#        [0.5669617 ],
#        [0.56264674],
#        [0.56477243],
#        [0.56948828],
#        [0.57572579],
#        [0.58119458],
#        [0.58946325],
#        [0.59567138],
#        [0.59859261],
#        [0.59860421],
#        [0.59859897],
#        [0.59861677],
#        [0.59879681],
#        [0.59898019],
#        [0.59898027],
#        [0.59898035],
#        [0.59898031],
#        [0.59898027],
#        [0.59898041],
#        [0.59898021],
#        [0.59898029],
#        [0.5989803 ],
#        [0.5989781 ],
#        [0.59898035],
#        [0.59758735],
#        [0.59245474],
#        [0.58331332],
#        [0.57624353],
#        [0.57084581],
#        [0.56464252],
#        [0.56282148],
#        [0.56785019],
#        [0.56069717],
#        [0.55196646],
#        [0.54417556],
#        [0.53676992],
#        [0.52773884],
#        [0.51633916],
#        [0.50618558],
#        [0.49946394],
#        [0.49013284],
#        [0.48415977],
#        [0.47650854],
#        [0.46923628],
#        [0.46453935],
#        [0.46009954],
#        [0.45623642],
#        [0.45298016],
#        [0.44890503],
#        [0.44525419],
#        [0.44110898],
#        [0.43771472],
#        [0.43605348],
#        [0.44080227],
#        [0.45126188],
#        [0.46156069],
#        [0.47257171],
#        [0.48032216],
#        [0.48803715],
#        [0.5002894 ],
#        [0.51103551],
#        [0.52113999],
#        [0.53097673],
#        [0.54100642],
#        [0.55083807],
#        [0.5604566 ],
#        [0.57007836],
#        [0.57823924],
#        [0.58595137],
#        [0.59601643],
#        [0.6002375 ],
#        [0.60037621],
#        [0.60036399],
#        [0.60134358],
#        [0.60569035],
#        [0.61494429],
#        [0.62206523],
#        [0.62929484],
#        [0.63734553],
#        [0.64525249],
#        [0.65158435],
#        [0.65742588],
#        [0.66518899],
#        [0.67368272],
#        [0.67509025],
#        [0.67513212],
#        [0.67518615],
#        [0.67518611],
#        [0.67518623],
#        [0.67518605],
#        [0.67518611],
#        [0.67518609],
#        [0.67518526],
#        [0.67518605],
#        [0.6751861 ],
#        [0.67505196],
#        [0.67468674],
#        [0.67248211],
#        [0.66194075],
#        [0.65805565],
#        [0.65860448],
#        [0.65910252],
#        [0.65972065],
#        [0.66025194],
#        [0.6614703 ],
#        [0.66591013],
#        [0.66993935],
#        [0.6730191 ],
#        [0.67456304],
#        [0.67450544],
#        [0.67411762],
#        [0.67123601],
#        [0.66816155],
#        [0.66530473],
#        [0.66239424],
#        [0.65955399],
#        [0.65900964],
#        [0.65859772],
#        [0.65737255],
#        [0.66130442],
#        [0.66447258],
#        [0.67537048],
#        [0.68597503],
#        [0.69739444],
#        [0.70842889],
#        [0.72147083],
#        [0.7307866 ],
#        [0.74201424],
#        [0.76081827],
#        [0.76803352],
#        [0.77831957],
#        [0.79325669],
#        [0.80086312],
#        [0.81297419],
#        [0.81872898],
#        [0.82982035],
#        [0.83868662],
#        [0.84436657],
#        [0.86160068],
#        [0.86871007],
#        [0.88157928],
#        [0.89058931],
#        [0.89969918],
#        [0.91084799],
#        [0.92098516],
#        [0.93178337],
#        [0.94226555],
#        [0.95177246],
#        [0.95881153],
#        [0.96570827],
#        [0.9736466 ],
#        [0.9815538 ],
#        [0.9868375 ],
#        [0.99037053],
#        [0.99029175],
#        [0.98652706],
#        [0.98113315],
#        [0.97360934],
#        [0.97123967],
#        [0.9713715 ],
#        [0.97188631],
#        [0.97159308],
#        [0.97148126],
#        [0.9717258 ],
#        [0.97185465],
#        [0.97191657],
#        [0.97215368],
#        [0.97238732],
#        [0.97189838],
#        [0.9710036 ],
#        [0.97203808],
#        [0.97221409],
#        [0.9662634 ],
#        [0.96384061],
#        [0.96383937],
#        [0.96383799],
#        [0.96383955],
#        [0.96408245],
#        [0.96432536],
#        [0.96931499],
#        [0.97931416],
#        [0.99215758],
#        [0.99818554],
#        [1.        ],
#        [0.99568333],
#        [0.9918199 ],
#        [0.98723921],
#        [0.98100887],
#        [0.97370115],
#        [0.96668984],
#        [0.95966852],
#        [0.95272378],
#        [0.94353734],
#        [0.93340505],
#        [0.92297134],
#        [0.91257182],
#        [0.90229332],
#        [0.89489281],
#        [0.88540516],
#        [0.87735011],
#        [0.8670649 ],
#        [0.85453211],
#        [0.84459514],
#        [0.83415631],
#        [0.8209013 ],
#        [0.81217407],
#        [0.79945285],
#        [0.7873188 ],
#        [0.77269218],
#        [0.76292899],
#        [0.751737  ],
#        [0.74091166],
#        [0.72441706],
#        [0.71428772],
#        [0.70339612],
#        [0.69162791],
#        [0.67983151],
#        [0.66788968],
#        [0.66094386],
#        [0.65830609],
#        [0.65702071],
#        [0.65853002],
#        [0.65986343],
#        [0.66295012],
#        [0.66590874],
#        [0.6694343 ],
#        [0.67235419],
#        [0.67443491],
#        [0.67447235],
#        [0.67435223],
#        [0.6720201 ],
#        [0.66828826],
#        [0.66345375],
#        [0.66035112],
#        [0.65733445],
#        [0.65371684],
#        [0.65063716],
#        [0.64679952],
#        [0.64373696],
#        [0.64042841],
#        [0.63671936],
#        [0.63366497],
#        [0.62909384],
#        [0.62621626],
#        [0.62271109],
#        [0.61719043],
#        [0.617271  ],
#        [0.62316962],
#        [0.61677866],
#        [0.61482685],
#        [0.60926789],
#        [0.60129339],
#        [0.59099789],
#        [0.58059025],
#        [0.57111703],
#        [0.56070668],
#        [0.55157882],
#        [0.54057802],
#        [0.52951327],
#        [0.51901657],
#        [0.50923353],
#        [0.49803989],
#        [0.48663695],
#        [0.48040705],
#        [0.47046771],
#        [0.46255048],
#        [0.44853375],
#        [0.4421599 ],
#        [0.43511711],
#        [0.43617556],
#        [0.44162143],
#        [0.44487507],
#        [0.44900537],
#        [0.45193421],
#        [0.45603577],
#        [0.45374696],
#        [0.45062311],
#        [0.44816184],
#        [0.44437477],
#        [0.44080999],
#        [0.43812996],
#        [0.43565183],
#        [0.43209898],
#        [0.42791129],
#        [0.42587025],
#        [0.42245368],
#        [0.42000642],
#        [0.41614126],
#        [0.41416041],
#        [0.41129392],
#        [0.40475115],
#        [0.40088191],
#        [0.39642203],
#        [0.39176406],
#        [0.38827948],
#        [0.38327122],
#        [0.37881809],
#        [0.3773538 ],
#        [0.37804154],
#        [0.37842288],
#        [0.37895665],
#        [0.37933626],
#        [0.37989466],
#        [0.38027988],
#        [0.3806846 ],
#        [0.3811666 ],
#        [0.38173012],
#        [0.38201305],
#        [0.38241363]])

# %%
y_pred
# Out:
# array([[0.6203768 ],
#        [0.6249372 ],
#        [0.62905693],
#        [0.6327807 ],
#        [0.63615304],
#        [0.6391706 ],
#        [0.6418342 ],
#        [0.644136  ],
#        [0.6460938 ],
#        [0.6477456 ],
#        [0.6491314 ],
#        [0.6502799 ],
#        [0.6512171 ],
#        [0.6519776 ],
#        [0.65259176],
#        [0.6531146 ],
#        [0.6537526 ],
#        [0.6546074 ],
#        [0.6557482 ],
#        [0.65730053],
#        [0.65928274],
#        [0.6616417 ],
#        [0.66430914],
#        [0.6672227 ],
#        [0.6703096 ],
#        [0.6735701 ],
#        [0.6770146 ],
#        [0.6806384 ],
#        [0.6844706 ],
#        [0.6885183 ],
#        [0.69279885],
#        [0.69724685],
#        [0.7018617 ],
#        [0.7066663 ],
#        [0.71158075],
#        [0.7165468 ],
#        [0.7215762 ],
#        [0.7267142 ],
#        [0.732003  ],
#        [0.7374927 ],
#        [0.74314964],
#        [0.749018  ],
#        [0.75504947],
#        [0.7612005 ],
#        [0.76743215],
#        [0.7737169 ],
#        [0.78001535],
#        [0.78626454],
#        [0.79245746],
#        [0.7985787 ],
#        [0.8045675 ],
#        [0.8103729 ],
#        [0.8159213 ],
#        [0.821104  ],
#        [0.8258271 ],
#        [0.83001375],
#        [0.83359617],
#        [0.83662367],
#        [0.8391586 ],
#        [0.8412918 ],
#        [0.8430525 ],
#        [0.844485  ],
#        [0.8456435 ],
#        [0.8464591 ],
#        [0.8469625 ],
#        [0.84720194],
#        [0.8472319 ],
#        [0.84709626],
#        [0.84685415],
#        [0.84651643],
#        [0.84613216],
#        [0.8457183 ],
#        [0.8452824 ],
#        [0.84484893],
#        [0.84442896],
#        [0.8440341 ],
#        [0.84366864],
#        [0.8433384 ],
#        [0.84305406],
#        [0.8428177 ],
#        [0.84274846],
#        [0.8429642 ],
#        [0.8434936 ],
#        [0.84428316],
#        [0.8452058 ],
#        [0.8460818 ],
#        [0.8467526 ],
#        [0.84710664],
#        [0.8470796 ],
#        [0.8465467 ],
#        [0.84544903],
#        [0.8437597 ],
#        [0.84147674],
#        [0.83858174],
#        [0.83510196],
#        [0.83105934],
#        [0.8264788 ],
#        [0.82140297],
#        [0.81584126],
#        [0.8098681 ],
#        [0.803542  ],
#        [0.796891  ],
#        [0.7899852 ],
#        [0.78290707],
#        [0.7757646 ],
#        [0.7686797 ],
#        [0.7617414 ],
#        [0.7550141 ],
#        [0.7484749 ],
#        [0.7421073 ],
#        [0.7358978 ],
#        [0.7297794 ],
#        [0.72371936],
#        [0.71773756],
#        [0.71183187],
#        [0.70598847],
#        [0.7001855 ],
#        [0.69442403],
#        [0.6886379 ],
#        [0.6828051 ],
#        [0.6768656 ],
#        [0.6707841 ],
#        [0.6646344 ],
#        [0.6584806 ],
#        [0.652463  ],
#        [0.64671445],
#        [0.6413465 ],
#        [0.63643575],
#        [0.6320351 ],
#        [0.6281811 ],
#        [0.6248549 ],
#        [0.6220258 ],
#        [0.6196638 ],
#        [0.6176952 ],
#        [0.6160281 ],
#        [0.6145602 ],
#        [0.61320597],
#        [0.6119022 ],
#        [0.61058986],
#        [0.60925347],
#        [0.6078535 ],
#        [0.60635716],
#        [0.6047695 ],
#        [0.60306287],
#        [0.6012545 ],
#        [0.59933347],
#        [0.59732693],
#        [0.5952345 ],
#        [0.5930909 ],
#        [0.5909193 ],
#        [0.588724  ],
#        [0.58656305],
#        [0.5844576 ],
#        [0.5824337 ],
#        [0.5804705 ],
#        [0.57843715],
#        [0.5762373 ],
#        [0.5737736 ],
#        [0.5709883 ],
#        [0.56785065],
#        [0.564323  ],
#        [0.5603975 ],
#        [0.55604446],
#        [0.55128783],
#        [0.54614747],
#        [0.54062027],
#        [0.5347475 ],
#        [0.52859014],
#        [0.5222003 ],
#        [0.51561284],
#        [0.50884336],
#        [0.5019381 ],
#        [0.49498942],
#        [0.4881067 ],
#        [0.48147285],
#        [0.47524554],
#        [0.4695282 ],
#        [0.4644094 ],
#        [0.45991775],
#        [0.45606774],
#        [0.45276788],
#        [0.4499099 ],
#        [0.44740468],
#        [0.44518107],
#        [0.44315097],
#        [0.44125393],
#        [0.43943378],
#        [0.4376701 ],
#        [0.4359304 ],
#        [0.43419954],
#        [0.432459  ],
#        [0.43069065],
#        [0.4289053 ],
#        [0.4271074 ],
#        [0.42527488],
#        [0.42335597],
#        [0.42134187],
#        [0.4192281 ],
#        [0.41702157],
#        [0.41470385],
#        [0.41225016],
#        [0.4096967 ],
#        [0.40707523],
#        [0.40446326],
#        [0.40192628],
#        [0.3995107 ],
#        [0.3972572 ],
#        [0.39518464],
#        [0.39332864],
#        [0.39169317],
#        [0.3902724 ],
#        [0.38905764],
#        [0.38803607],
#        [0.387182  ],
#        [0.38644284],
#        [0.38575894],
#        [0.38500294],
#        [0.38404703],
#        [0.38280863],
#        [0.3812592 ],
#        [0.37939397],
#        [0.37725353],
#        [0.37497   ],
#        [0.3728146 ],
#        [0.37100267],
#        [0.3696764 ],
#        [0.36889893],
#        [0.36871803],
#        [0.36916322],
#        [0.37024966],
#        [0.37198046],
#        [0.37437943],
#        [0.37739742],
#        [0.3810572 ],
#        [0.3852956 ],
#        [0.39005393],
#        [0.3953034 ],
#        [0.40099147],
#        [0.40709528],
#        [0.41359138],
#        [0.42039576],
#        [0.42737848],
#        [0.4343689 ],
#        [0.44121075],
#        [0.4478029 ],
#        [0.4540658 ],
#        [0.45995513],
#        [0.46542192],
#        [0.47044536],
#        [0.47501522],
#        [0.47911936],
#        [0.4827426 ],
#        [0.48591813],
#        [0.48868316],
#        [0.49100462],
#        [0.49271995],
#        [0.49373466],
#        [0.4940315 ],
#        [0.4936102 ],
#        [0.49237785],
#        [0.4903147 ],
#        [0.4874409 ],
#        [0.48382473],
#        [0.479567  ],
#        [0.47471726],
#        [0.46936405],
#        [0.4635738 ],
#        [0.45739678],
#        [0.45094633],
#        [0.44429073],
#        [0.43751493],
#        [0.4306148 ],
#        [0.42360047],
#        [0.41656005],
#        [0.40963447],
#        [0.40295264],
#        [0.39660817],
#        [0.39076307],
#        [0.3855275 ],
#        [0.38097134],
#        [0.37720492],
#        [0.37425208],
#        [0.3721541 ],
#        [0.37084416],
#        [0.37019104],
#        [0.37006024],
#        [0.37032208],
#        [0.37088677],
#        [0.37165216],
#        [0.37252757],
#        [0.37345386],
#        [0.37437904],
#        [0.3752823 ],
#        [0.37613523],
#        [0.37692717],
#        [0.37765583],
#        [0.37830323],
#        [0.37887952],
#        [0.3793886 ],
#        [0.3798892 ],
#        [0.38045883],
#        [0.38111708],
#        [0.38189203],
#        [0.3828095 ],
#        [0.38389888],
#        [0.38514847],
#        [0.38659152],
#        [0.38832116],
#        [0.39031133],
#        [0.3926646 ],
#        [0.39538422],
#        [0.3984628 ],
#        [0.40195376],
#        [0.40584487],
#        [0.41008595],
#        [0.41464496],
#        [0.41950452],
#        [0.42463133],
#        [0.42998666],
#        [0.43556437],
#        [0.44132888],
#        [0.4472507 ],
#        [0.453254  ],
#        [0.45925725],
#        [0.46519342],
#        [0.47098708],
#        [0.47654516],
#        [0.4817907 ],
#        [0.48666576],
#        [0.4911519 ],
#        [0.4952353 ],
#        [0.49892113],
#        [0.50221854],
#        [0.5051483 ],
#        [0.50772846],
#        [0.50996846],
#        [0.51192003],
#        [0.5135838 ],
#        [0.51502687],
#        [0.51639706],
#        [0.5176772 ],
#        [0.5188128 ],
#        [0.5198499 ],
#        [0.5208548 ],
#        [0.5219107 ],
#        [0.5230817 ],
#        [0.5244576 ],
#        [0.52606505],
#        [0.5278826 ],
#        [0.52982825],
#        [0.53184044],
#        [0.53385824],
#        [0.5358319 ],
#        [0.5377298 ],
#        [0.53953093],
#        [0.5412146 ],
#        [0.5427683 ],
#        [0.54418725],
#        [0.5454711 ],
#        [0.54662347],
#        [0.54765105],
#        [0.5485621 ],
#        [0.5493656 ],
#        [0.55007094],
#        [0.55066615],
#        [0.55108464],
#        [0.55120414],
#        [0.5509405 ],
#        [0.5503118 ],
#        [0.54932266],
#        [0.54801255],
#        [0.5465456 ],
#        [0.54488194],
#        [0.5429688 ],
#        [0.54076207],
#        [0.53825396],
#        [0.5354246 ],
#        [0.5322267 ],
#        [0.5286365 ],
#        [0.5246975 ],
#        [0.52041596],
#        [0.51585716],
#        [0.51105696],
#        [0.5060541 ],
#        [0.50092274],
#        [0.4957303 ],
#        [0.4905408 ],
#        [0.4854141 ],
#        [0.48038304],
#        [0.47547576],
#        [0.4707024 ],
#        [0.46607763],
#        [0.46164072],
#        [0.45752776],
#        [0.45393622],
#        [0.45099652],
#        [0.44881228],
#        [0.4474084 ],
#        [0.44676062],
#        [0.4468864 ],
#        [0.44783354],
#        [0.44957316],
#        [0.45205012],
#        [0.45520815],
#        [0.45899302],
#        [0.46334866],
#        [0.4682062 ],
#        [0.4734707 ],
#        [0.47907385],
#        [0.48496878],
#        [0.49104527],
#        [0.49713817],
#        [0.5030996 ],
#        [0.5088379 ],
#        [0.514339  ],
#        [0.51968086],
#        [0.5249123 ],
#        [0.5300755 ],
#        [0.5352223 ],
#        [0.5403881 ],
#        [0.5455715 ],
#        [0.5507417 ],
#        [0.5559023 ],
#        [0.56108874],
#        [0.5662165 ],
#        [0.57120526],
#        [0.57597667],
#        [0.5804527 ],
#        [0.584601  ],
#        [0.5884012 ],
#        [0.59184563],
#        [0.5949361 ],
#        [0.59768456],
#        [0.6001093 ],
#        [0.60223144],
#        [0.60407823],
#        [0.60566986],
#        [0.6069879 ],
#        [0.607923  ],
#        [0.60848325],
#        [0.6087402 ],
#        [0.6087597 ],
#        [0.608596  ],
#        [0.6082891 ],
#        [0.60791   ],
#        [0.6075575 ],
#        [0.6073022 ],
#        [0.60718644],
#        [0.6072196 ],
#        [0.6073726 ],
#        [0.60760033],
#        [0.6078281 ],
#        [0.60801995],
#        [0.6081295 ],
#        [0.6081165 ],
#        [0.607955  ],
#        [0.60766447],
#        [0.60727006],
#        [0.6067839 ],
#        [0.6062983 ],
#        [0.60587996],
#        [0.605702  ],
#        [0.60590005],
#        [0.6065895 ],
#        [0.607845  ],
#        [0.6097479 ],
#        [0.61231536],
#        [0.61551315],
#        [0.6194224 ],
#        [0.62393665],
#        [0.62899464],
#        [0.6346062 ],
#        [0.640656  ],
#        [0.6470973 ],
#        [0.65380293],
#        [0.66074646],
#        [0.6678749 ],
#        [0.6750954 ],
#        [0.68250436],
#        [0.6900405 ],
#        [0.6977288 ],
#        [0.7055291 ],
#        [0.713408  ],
#        [0.721367  ],
#        [0.729384  ],
#        [0.7374582 ],
#        [0.74558747],
#        [0.7537307 ],
#        [0.7618379 ],
#        [0.76983136],
#        [0.7776956 ],
#        [0.78541726],
#        [0.7929541 ],
#        [0.80023855],
#        [0.80718625],
#        [0.8136557 ],
#        [0.8194922 ],
#        [0.8246245 ],
#        [0.829034  ],
#        [0.83276075],
#        [0.8359111 ],
#        [0.83853054],
#        [0.8407111 ],
#        [0.84249747],
#        [0.8439584 ],
#        [0.84515685],
#        [0.8460929 ],
#        [0.846851  ],
#        [0.8474299 ],
#        [0.847859  ],
#        [0.848178  ],
#        [0.84840006],
#        [0.848454  ],
#        [0.84832704],
#        [0.84805346],
#        [0.8476694 ],
#        [0.8472139 ],
#        [0.8467158 ],
#        [0.84619486],
#        [0.84574294],
#        [0.8455235 ],
#        [0.8457088 ],
#        [0.84633577],
#        [0.8473543 ],
#        [0.8486043 ],
#        [0.8499501 ],
#        [0.8512382 ],
#        [0.8523306 ],
#        [0.8531136 ],
#        [0.85351336],
#        [0.8534794 ],
#        [0.85298514],
#        [0.85199046],
#        [0.8504597 ],
#        [0.84837085],
#        [0.8457195 ],
#        [0.8425197 ],
#        [0.83883846],
#        [0.83470213],
#        [0.8301728 ],
#        [0.82529515],
#        [0.820038  ],
#        [0.81442374],
#        [0.80847824],
#        [0.80218476],
#        [0.79560256],
#        [0.7887264 ],
#        [0.7815459 ],
#        [0.77401644],
#        [0.76618916],
#        [0.7581292 ],
#        [0.74989074],
#        [0.7414418 ],
#        [0.73282874],
#        [0.72408813],
#        [0.7152436 ],
#        [0.70631295],
#        [0.6973044 ],
#        [0.68830365],
#        [0.67944974],
#        [0.670887  ],
#        [0.66276604],
#        [0.65519494],
#        [0.648272  ],
#        [0.6420584 ],
#        [0.63658184],
#        [0.6318558 ],
#        [0.6278446 ],
#        [0.6244836 ],
#        [0.62170124],
#        [0.6193738 ],
#        [0.6173804 ],
#        [0.615609  ],
#        [0.61396456],
#        [0.61240673],
#        [0.6108798 ],
#        [0.6093623 ],
#        [0.60780054],
#        [0.6061901 ],
#        [0.60452056],
#        [0.6028039 ],
#        [0.60101557],
#        [0.5991419 ],
#        [0.5971997 ],
#        [0.59519196],
#        [0.5930924 ],
#        [0.5909458 ],
#        [0.58888555],
#        [0.5868446 ],
#        [0.5848217 ],
#        [0.5827681 ],
#        [0.5805958 ],
#        [0.5782034 ],
#        [0.5755061 ],
#        [0.57246125],
#        [0.56903136],
#        [0.5652216 ],
#        [0.56101197],
#        [0.55640286],
#        [0.55141026],
#        [0.54606694],
#        [0.5403756 ],
#        [0.53434855],
#        [0.52808374],
#        [0.52160823],
#        [0.51498204],
#        [0.5081568 ],
#        [0.5012119 ],
#        [0.4942078 ],
#        [0.48731503],
#        [0.48075056],
#        [0.4746417 ],
#        [0.46910018],
#        [0.46418646],
#        [0.4599182 ],
#        [0.45619193],
#        [0.4529594 ],
#        [0.4501127 ],
#        [0.44756645],
#        [0.44524512],
#        [0.44309938],
#        [0.44108528],
#        [0.4391484 ],
#        [0.4372431 ],
#        [0.4353583 ],
#        [0.43347964],
#        [0.4316052 ],
#        [0.42971155],
#        [0.4278083 ],
#        [0.42589983],
#        [0.42393017],
#        [0.42187187],
#        [0.4197302 ],
#        [0.41748744],
#        [0.41518047],
#        [0.41276753],
#        [0.41025534],
#        [0.40766335],
#        [0.40505674],
#        [0.40251088],
#        [0.40007567],
#        [0.3977929 ],
#        [0.3956845 ],
#        [0.39378834],
#        [0.39210874],
#        [0.3906389 ],
#        [0.38937673],
#        [0.38830578]], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error

# Calculate MSE between predicted and actual values
error = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error on the Testing Set: {error}")
# Out:
# Mean Squared Error on the Testing Set: 0.007038506215673487

# %%
# Get the original data for predicted cells and add it to testing set as a new column
# Convert predictions to a DataFrame for easier concatenation
predictions_df = pd.DataFrame(y_pred, columns=['Predicted_Latitude'])

# %%
predictions_df.head()
# Out:
#    Predicted_Latitude
# 0            0.620377
# 1            0.624937
# 2            0.629057
# 3            0.632781
# 4            0.636153

# %%
# Convert the predictions (y_pred) into a DataFrame for easy handling with timestamps
# We assume `testing_set.index[input_window_size:]` matches the `y_pred` in length
predicted_latitudes = pd.DataFrame(y_pred, index=testing_set.index[input_window_size:], columns=['Predicted_Latitude'])

# Add the 'Latitude' column from `testing_set` as the true values for comparison
testing_latitudes = testing_set[['Latitude']].iloc[input_window_size:]  # Skip initial window

# Define the months for filtering and specific timestamps for illustration
months = {
    'April': '2024-04',
    'May': '2024-05',
    'June': '2024-06',
    'July': '2024-07',
    'August': '2024-08'
}

# Plot each month's data
for month_name, month_str in months.items():
    # Filter data for the entire month
    monthly_actual_data = testing_latitudes[testing_latitudes.index.to_period('M') == month_str]
    monthly_predicted_data = predicted_latitudes[predicted_latitudes.index.to_period('M') == month_str]
    
    # Plot actual vs predicted latitude values for the month
    plt.figure(figsize=(12, 6))
    plt.plot(monthly_actual_data.index, monthly_actual_data['Latitude'], label='Actual Latitude', color='blue')
    plt.plot(monthly_predicted_data.index, monthly_predicted_data['Predicted_Latitude'], label='Predicted Latitude', color='orange')
    
    # Formatting the plot
    plt.title(f'{month_name} 2024 - Latitude vs Predicted Latitude')
    plt.xlabel('Received Timestamp')
    plt.ylabel('Latitude')
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
best_model.save('Latitude model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
y_test_original = scaler.inverse_transform(y_test.reshape(-1, 1))  
y_pred_original = scaler.inverse_transform(y_pred.reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 y_test_original = scaler.inverse_transform(y_test.reshape(-1, 1))
#       2 y_pred_original = scaler.inverse_transform(y_pred.reshape(-1, 1))
#
# File /anaconda/envs/jupyter_env/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:574, in MinMaxScaler.inverse_transform(self, X)
#     564 xp, _ = get_namespace(X)
#     566 X = check_array(
#     567     X,
#     568     copy=self.copy,
#    (...)
#     571     force_all_finite="allow-nan",
#     572 )
# --> 574 X -= self.min_
#     575 X /= self.scale_
#     576 return X
#
# ValueError: non-broadcastable output operand with shape (648,1) doesn't match the broadcast shape (648,2)
